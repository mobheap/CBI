# %%
import pandas as pd

# %%
data = pd.read_csv("APM tools Gartner.csv")

# %%
data.columns
# Out:
# Index(['Name', 'Rating-5', 'Number of reviews', 'Description'], dtype='object')

# %%
data = data.sort_values(by='Number of reviews', ascending=False)

# %%
data
# Out:
#                                       Name  Rating-5  Number of reviews  \
# 0                                Dynatrace       4.6               1538
# 1                                New Relic       4.5               1391
# 2                              AppDynamics       4.5                984
# 3                                  Datadog       4.4                781
# 4                        Amazon CloudWatch       4.5                563
# 5        ManageEngine Applications Manager       4.6                431
# 6                            Azure Monitor       4.5                333
# 7                IBM Instana Observability       4.3                298
# 8                    Elastic Observability       4.4                247
# 9               Splunk Observability Cloud       4.3                176
# 10                             LM Envision       4.4                174
# 11                           Grafana Cloud       4.5                115
# ...
