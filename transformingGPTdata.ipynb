# %%
import pandas as pd

# %%
data = pd.read_csv('data/raw/Monitoring_Tool_Comparison.csv')
data
# Out:
#                        Feature  \
# 0                Core Offering
# 1                    Key Focus
# 2      Monitoring Capabilities
# 3              AI & Automation
# 4                 Cloud-Native
# 5                 Integrations
# 6                  Ease of Use
# 7                      Pricing
# 8   Real User Monitoring (RUM)
# 9               Log Management
# 10           Mobile Monitoring
# 11      Dashboards & Reporting
# 12                Trial Period
#
#                                             Dynatrace  \
# 0                            Full-stack observability
# 1                   AIOps, APM, Cloud, Infrastructure
# 2   APM, Infrastructure, Logs, Real User Monitorin...
# 3   Strong AI-powered capabilities for anomaly det...
# 4     Yes, designed for cloud and hybrid environments
# 5   Extensive integrations with cloud, containers,...
# 6   User-friendly, with automated root-cause analy...
# 7   Subscription-based, based on the number of hos...
# ...

# %%
data = data.set_index('Feature').T
data
# Out:
# Feature                                Core Offering  \
# Dynatrace                   Full-stack observability
# New Relic         Application performance monitoring
# Datadog      Full-stack observability and monitoring
# AppDynamics       Application performance management
#
# Feature                                         Key Focus  \
# Dynatrace               AIOps, APM, Cloud, Infrastructure
# New Relic                       APM, Infrastructure, Logs
# Datadog             Cloud monitoring, Infrastructure, APM
# AppDynamics  APM, Cloud monitoring, Business Intelligence
#
# Feature                                Monitoring Capabilities  \
# Dynatrace    APM, Infrastructure, Logs, Real User Monitorin...
# New Relic                       APM, Infrastructure, Logs, RUM
# Datadog                         APM, Infrastructure, Logs, RUM
# AppDynamics  APM, Infrastructure, Business Transaction Moni...
#
# Feature                                        AI & Automation  \
# ...

# %%
data.to_csv('data/GPT_comparison.csv', index=False)
